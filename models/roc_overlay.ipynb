# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')


from sklearn.metrics import roc_curve, auc

import sys
sys.path.append("../")
from src.clean_churn_data import clean_churn_data
from src.roc import plot_roc_curve
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# import data

nn_y_hat = np.loadtxt('../data/nn_y_hat.txt')
nn_y_test = np.loadtxt('../data/nn_y_test.txt')

rf_y_hat = np.loadtxt('../data/rf_y_hat.txt')
rf_y_test = np.loadtxt('../data/rf_y_test.txt')

gb_y_hat = np.loadtxt('../data/gbc_yproba.txt')
gb_y_test = np.loadtxt('../data/gbc_ytrue.txt')

# %%
# plot ROC

fig, ax = plt.subplots(figsize=(8,8))

ax, tpr, fpr, thresholds = plot_roc_curve(nn_y_hat, nn_y_test, ax, title="Neural Network")
ax, tpr, fpr, thresholds = plot_roc_curve(rf_y_hat, rf_y_test, ax, title="Random Forest")
ax, tpr, fpr, thresholds = plot_roc_curve(gb_y_hat, gb_y_test, ax, title="Gradient Boosting")

fig.savefig('../img/roc_overlay.png')
